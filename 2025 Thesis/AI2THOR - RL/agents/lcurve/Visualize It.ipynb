# %%
import pickle
import matplotlib
import matplotlib.pyplot as plt

import torch

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# %% [markdown]
# ## Task 1

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK1GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

# plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bowl)')

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bread)')

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

# place the legend
plt.legend()
    
plt.show()

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK1GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (3 Objects)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

lcurve_path = "./episode_scores_WO_ATT_9OBJ_TASK1GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

scores_t = torch.tensor(episode_scores, dtype=torch.float)

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (9 Objects)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Task 2

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

# plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 20

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='ICL (Average Reward)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='ICL (Standard Deviation)')

# place the legend
# plt.legend()
    
# plt.show()

lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN_WOCL"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)
    
scores_t = torch.tensor(episode_scores[:6000], dtype=torch.float)

# take 100 episode averages and plot them
window_size = 20

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Baseline (Average Reward)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Baseline (Standard Deviation)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bowl)')

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bread)')

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

# place the legend
plt.legend()
    
plt.show()

# %% [markdown]
# ## Task 3

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK3GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

# plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bowl)')

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bread)')

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

# place the legend
plt.legend()
    
plt.show()

# %% [markdown]
# ## Task 4

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK4GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

# plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bowl)')

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bread)')

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

# place the legend
plt.legend()
    
plt.show()

# %% [markdown]
# ## WOCL

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN_WOCL"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bowl)')

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bread)')

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Negative Reward

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN_NETREWARD"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bowl)')

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bread)')

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Scaleup (Task 1)

# %%
lcurve_path = "./episode_scores_WO_ATT_9OBJ_TASK1GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::9] # bowl
second_es = episode_scores[1::9] # bread
third_es = episode_scores[2::9] # vase

fourth_es = episode_scores[3::9] # knife
fifth_es = episode_scores[4::9] # potato
sixth_es = episode_scores[5::9] # cup

seventh_es = episode_scores[6::9] # pot
eight_es = episode_scores[7::9] # ladle
ninth_es = episode_scores[8::9] # plate

plt.figure(figsize=(8, 6))
plt.clf()

############### DIVIDER ###############

scores_t = torch.tensor(first_es, dtype=torch.float)

plt.title(f'Training Results')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bowl)')

############### DIVIDER ###############

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Bread)')

############### DIVIDER ###############

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

############### DIVIDER ###############

scores_t = torch.tensor(fourth_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Knife)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

############### DIVIDER ###############

scores_t = torch.tensor(fifth_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Potato)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

############### DIVIDER ###############

scores_t = torch.tensor(sixth_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Cup)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

############### DIVIDER ###############

scores_t = torch.tensor(seventh_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Pot)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

############### DIVIDER ###############

scores_t = torch.tensor(eight_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Ladle)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

############### DIVIDER ###############

scores_t = torch.tensor(ninth_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Plate)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Standard Deviation (Vase)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Scaleup (Task 2)

# %% [markdown]
# ## Scaleup (Task 3)

# %% [markdown]
# ## Scaleup (Task 4)

# %% [markdown]
# ---
