# %%
import pickle
import matplotlib
import matplotlib.pyplot as plt

import torch

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# %% [markdown]
# ## Max Time (100)

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN_MAX100"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

# plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Max Time (200)

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

# plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Max Time (400)

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN_MAX400"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

# plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Epsilon (0.9)

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

# plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Epsilon (0.75)

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN_EPS075"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

# plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Epsilon (0.50)

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN_EPS050"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

# plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Reward Scaling (Incremental)

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

# plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Reward Scaling (Norm)

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN_NORM"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

# plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Reward Scaling (Div10)

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN_DIV10"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results (All)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), color='red', label='Average Reward (All)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), color='red', alpha=0.2, label='Standard Deviation (All)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %%
first_es = episode_scores[0::3] # bowl
second_es = episode_scores[1::3] # bread
third_es = episode_scores[2::3] # vase

plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(first_es, dtype=torch.float)

# plt.title(f'Training Results (Bowl, Bread, Vase)')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 100

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bowl)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(second_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Bread)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

scores_t = torch.tensor(third_es, dtype=torch.float)

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='Average Reward (Vase)')
plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2)

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
    
plt.show()

# %% [markdown]
# ## Positive vs Neutral Reward

# %%
lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)

# %%
plt.figure(figsize=(8, 6))
plt.clf()
scores_t = torch.tensor(episode_scores, dtype=torch.float)

plt.title(f'Training Results')
plt.xlabel('Episode')
plt.ylabel('Cumulative Rewards')

# take 100 episode averages and plot them
window_size = 20

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='ICL (Positive Reward)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='ICL (Standard Deviation)')

# place the legend
# plt.legend()
    
# plt.show()

lcurve_path = "./episode_scores_WO_ATT_3OBJ_TASK2GEN_NETREWARD"

with open(lcurve_path, "rb") as fp:
    episode_scores = pickle.load(fp)
    
scores_t = torch.tensor(episode_scores[:6000], dtype=torch.float)

# take 100 episode averages and plot them
window_size = 20

# calculate fixed-size window averages (means) and standard deviations
means = scores_t.unfold(0, window_size, 1).mean(1).view(-1)
std_deviation = scores_t.unfold(0, window_size, 1).std(1).view(-1)

# pad the start with NaNs to align the plots correctly
means = torch.cat((torch.zeros(window_size-1), means))
std_deviation = torch.cat((torch.zeros(window_size-1), std_deviation))

# calculate the x-axis indices for plotting
x_values = torch.arange(len(scores_t))

# plot means with standard deviation as shaded area
plt.plot(x_values.numpy(), means.numpy(), label='ICL (Neutral Reward)')
# plt.fill_between(x_values.numpy(), (means-std_deviation).numpy(), (means+std_deviation).numpy(), alpha=0.2, label='Baseline (Standard Deviation)')

# place the legend
plt.legend(loc='lower right', fontsize='x-large')
plt.show()

# %% [markdown]
# ---
