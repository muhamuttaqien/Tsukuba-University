# %%
import random
import pandas as pd
import matplotlib.pyplot as plt

import ai2thor
import ai2thor_colab
from ai2thor_colab import plot_frames, side_by_side
from ai2thor.controller import Controller

from IPython.display import clear_output

# %%
from ai2thor.platform import CloudRendering
controller = Controller(platform=CloudRendering)

# %% [markdown]
# ## Workspace

# %%
def show_object_detected(controller):

    data = controller.last_event.metadata['objects']

    df_data = pd.DataFrame(data)

    df_object = df_data[(df_data['name'] == 'Toaster_f745e839') | (df_data['name'] == 'CoffeeMachine_61ed6a3e') | 
                        (df_data['name'] == 'Microwave_e71f2758') | (df_data['name'] == 'Fridge_22a96a15') | 
                        (df_data['name'] == 'LightSwitch_43d10eaa')]
    
    print('Object detected:')
    print(dict(df_object['name'][df_object['visible'] == True]))

# %%
floor_index = random.randint(0, 30)
floor_index = 26

controller = Controller(
    agentMode = "default", # arm
    visibilityDistance = 0.75,
    scene = f"FloorPlan{floor_index}",

    # step sizes
    gridSize = 0.25,
    snapToGrid = True,
    rotateStepDegrees = 90,

    # image modalities
    renderInstanceSegmentation = False,
    renderDepthImage = False,
    renderSemanticSegmentation = False,
    renderNormalsImage = False,
    
    # camera properties
    width = 1200,
    height = 800,
    fieldOfView = 120
)

# %%
w = "MoveAhead"
a = "MoveLeft"
s = "MoveBack"
d = "MoveRight"

l = "RotateLeft"
r = "RotateRight"

# %%
data = controller.last_event.metadata['objects']
df_data = pd.DataFrame(data)

# %%
command = s

event = controller.step(command)
agent_position = event.metadata["agent"]["position"]

print("Agent position:")
print(agent_position)
show_object_detected(controller)

plot_frames(controller.last_event)
# Out:
# Agent position:
# {'x': -2.75, 'y': 0.9015909433364868, 'z': 1.5}
# Object detected:
# {}

# %% [markdown]
# ---

# %%
data = controller.last_event.metadata['objects']
data
# Out:
# [{'name': 'Apple_499e3527',
#   'position': {'x': -1.6397528648376465,
#    'y': 0.9610141515731812,
#    'z': 0.5028530359268188},
#   'rotation': {'x': 89.87179565429688,
#    'y': 187.67654418945312,
#    'z': 187.66976928710938},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': False,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': True,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': True,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.20000000298023224,
#   'salientMaterials': ['Food'],
#   'receptacleObjectIds': None,
#   'distance': 1.49347984790802,
#   'objectType': 'Apple',
#   'objectId': 'Apple|-01.64|+00.96|+00.50',
#   'assetId': 'Apple_26',
#   'parentReceptacles': ['CounterTop|-01.37|+00.95|+00.35'],
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-1.5962039232254028,
#      1.0033351182937622,
#      0.5577768087387085],
#     [-1.5962039232254028, 1.0033351182937622, 0.4455275535583496],
#     [-1.5962039232254028, 0.9169818162918091, 0.5577768087387085],
#     [-1.5962039232254028, 0.9169818162918091, 0.4455275535583496],
#     [-1.68254554271698, 1.0033351182937622, 0.5577768087387085],
#     [-1.68254554271698, 1.0033351182937622, 0.4455275535583496],
#     [-1.68254554271698, 0.9169818162918091, 0.5577768087387085],
#     [-1.68254554271698, 0.9169818162918091, 0.4455275535583496]],
#    'center': {'x': -1.6393747329711914,
#     'y': 0.9601584672927856,
#     'z': 0.501652181148529},
#    'size': {'x': 0.08634161949157715,
#     'y': 0.08635330200195312,
#     'z': 0.11224925518035889}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-1.5962263345718384,
#      0.9170073866844177,
#      0.44549760222435],
#     [-1.6825648546218872, 0.9170352816581726, 0.44550827145576477],
#     [-1.6825369596481323, 1.0033737421035767, 0.4455575942993164],
#     [-1.5961984395980835, 1.0033458471298218, 0.4455469250679016],
#     [-1.5962125062942505, 0.9169432520866394, 0.5577468276023865],
#     [-1.6825509071350098, 0.9169711470603943, 0.5577574968338013],
#     [-1.6825230121612549, 1.0033096075057983, 0.5578068494796753],
#     [-1.5961846113204956, 1.0032817125320435, 0.5577961206436157]]}},
#  {'name': 'Bowl_bd22067b',
#   'position': {'x': -2.637242555618286,
#    'y': 0.7214791178703308,
#    'z': 2.868403196334839},
#   'rotation': {'x': 359.9196472167969,
#    'y': 0.008143287152051926,
#    'z': 0.38896721601486206},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': True,
#   'isBroken': False,
#   'canFillWithLiquid': True,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': True,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': True,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.4699999988079071,
#   'salientMaterials': ['Ceramic'],
#   'receptacleObjectIds': [],
#   'distance': 1.3848038911819458,
#   'objectType': 'Bowl',
#   'objectId': 'Bowl|-02.64|+00.72|+02.87',
#   'assetId': 'Bowl_26',
#   'parentReceptacles': ['DiningTable|-02.73|00.00|+02.61'],
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-2.551745891571045,
#      0.8164499998092651,
#      2.9566943645477295],
#     [-2.551745891571045, 0.8164499998092651, 2.7818076610565186],
#     [-2.551745891571045, 0.7198876142501831, 2.9566943645477295],
#     [-2.551745891571045, 0.7198876142501831, 2.7818076610565186],
#     [-2.7230162620544434, 0.8164499998092651, 2.9566943645477295],
#     [-2.7230162620544434, 0.8164499998092651, 2.7818076610565186],
#     [-2.7230162620544434, 0.7198876142501831, 2.9566943645477295],
#     [-2.7230162620544434, 0.7198876142501831, 2.7818076610565186]],
#    'center': {'x': -2.637381076812744,
#     'y': 0.7681688070297241,
#     'z': 2.869251012802124},
#    'size': {'x': 0.17127037048339844,
#     'y': 0.09656238555908203,
#     'z': 0.17488670349121094}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-2.5511250495910645,
#      0.7211085557937622,
#      2.956798791885376],
#     [-2.7223851680755615, 0.7199459075927734, 2.956824541091919],
#     [-2.722409963607788, 0.7197002172470093, 2.781959056854248],
#     [-2.551149845123291, 0.720862865447998, 2.781933069229126],
#     [-2.5517730712890625, 0.8165730237960815, 2.956664562225342],
#     [-2.7230334281921387, 0.8154103755950928, 2.956690549850464],
#     [-2.7230582237243652, 0.8151646852493286, 2.781825065612793],
#     [-2.551797866821289, 0.8163273334503174, 2.781799077987671]]}},
#  {'name': 'Bread_fe4bb3e3',
#   'position': {'x': -2.8720459938049316,
#    'y': 0.7687849402427673,
#    'z': 2.4088075160980225},
#   'rotation': {'x': 359.9647216796875,
#    'y': 0.0002106537576764822,
#    'z': 0.5715054273605347},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': False,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': True,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': True,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.699999988079071,
#   'salientMaterials': ['Food'],
#   'receptacleObjectIds': None,
#   'distance': 0.9265332221984863,
#   'objectType': 'Bread',
#   'objectId': 'Bread|-02.87|+00.77|+02.41',
#   'assetId': 'Bread_26',
#   'parentReceptacles': ['DiningTable|-02.73|00.00|+02.61'],
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-2.761232852935791,
#      0.8064498901367188,
#      2.5707921981811523],
#     [-2.761232852935791, 0.8064498901367188, 2.2548537254333496],
#     [-2.761232852935791, 0.7169312238693237, 2.5707921981811523],
#     [-2.761232852935791, 0.7169312238693237, 2.2548537254333496],
#     [-2.981400966644287, 0.8064498901367188, 2.5707921981811523],
#     [-2.981400966644287, 0.8064498901367188, 2.2548537254333496],
#     [-2.981400966644287, 0.7169312238693237, 2.5707921981811523],
#     [-2.981400966644287, 0.7169312238693237, 2.2548537254333496]],
#    'center': {'x': -2.871316909790039,
#     'y': 0.7616905570030212,
#     'z': 2.412822961807251},
#    'size': {'x': 0.2201681137084961,
#     'y': 0.08951866626739502,
#     'z': 0.31593847274780273}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-2.7612178325653076,
#      0.7189135551452637,
#      2.5707902908325195],
#     [-2.9808545112609863, 0.7167211771011353, 2.5707926750183105],
#     [-2.980855941772461, 0.7165262699127197, 2.2548868656158447],
#     [-2.7612195014953613, 0.7187186479568481, 2.2548842430114746],
#     [-2.7621028423309326, 0.8075892925262451, 2.570735454559326],
#     [-2.9817395210266113, 0.8053969740867615, 2.570737838745117],
#     [-2.981741189956665, 0.805202066898346, 2.2548320293426514],
#     [-2.7621045112609863, 0.8073943853378296, 2.2548296451568604]]}},
#  {'name': 'ButterKnife_9d61f327',
#   'position': {'x': -2.210432291030884,
#    'y': 0.9183155298233032,
#    'z': 0.6197995543479919},
#   'rotation': {'x': 4.951887240167707e-05,
#    'y': 268.2579650878906,
#    'z': 90.00373840332031},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': False,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': True,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.07999999821186066,
#   'salientMaterials': ['Metal'],
#   'receptacleObjectIds': None,
#   'distance': 1.0325530767440796,
#   'objectType': 'ButterKnife',
#   'objectId': 'ButterKnife|-02.21|+00.92|+00.62',
#   'assetId': 'ButterKnife_1',
#   'parentReceptacles': ['CounterTop|-01.37|+00.95|+00.35'],
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-2.0785062313079834,
#      0.9236479997634888,
#      0.6379114985466003],
#     [-2.0785062313079834, 0.9236479997634888, 0.6085478663444519],
#     [-2.0785062313079834, 0.9169834852218628, 0.6379114985466003],
#     [-2.0785062313079834, 0.9169834852218628, 0.6085478663444519],
#     [-2.3474533557891846, 0.9236479997634888, 0.6379114985466003],
#     [-2.3474533557891846, 0.9236479997634888, 0.6085478663444519],
#     [-2.3474533557891846, 0.9169834852218628, 0.6379114985466003],
#     [-2.3474533557891846, 0.9169834852218628, 0.6085478663444519]],
#    'center': {'x': -2.212979793548584,
#     'y': 0.9203157424926758,
#     'z': 0.6232296824455261},
#    'size': {'x': 0.26894712448120117,
#     'y': 0.0066645145416259766,
#     'z': 0.029363632202148438}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-2.3474535942077637,
#      0.9236470460891724,
#      0.6297516822814941],
#     [-2.3474533557891846, 0.9169827103614807, 0.6297516226768494],
#     [-2.079151153564453, 0.9169841408729553, 0.6379115581512451],
#     [-2.0791513919830322, 0.9236485362052917, 0.6379116177558899],
#     [-2.346808671951294, 0.9236473441123962, 0.6085480451583862],
#     [-2.346808671951294, 0.9169830083847046, 0.6085479259490967],
#     [-2.0785064697265625, 0.9169844388961792, 0.6167078018188477],
#     [-2.0785064697265625, 0.9236488342285156, 0.6167079210281372]]}},
#  {'name': 'Cabinet_ebbe42fd',
#   'position': {'x': -0.518989086151123,
#    'y': 2.046686887741089,
#    'z': 0.3922911286354065},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 2.7414729595184326,
#   'objectType': 'Cabinet',
#   'objectId': 'Cabinet|-00.52|+02.05|+00.39',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.5189889669418335,
#      2.3358187675476074,
#      0.43286600708961487],
#     [-0.5189889669418335, 2.3358187675476074, 0.022988110780715942],
#     [-0.5189889669418335, 1.7575550079345703, 0.43286600708961487],
#     [-0.5189889669418335, 1.7575550079345703, 0.022988110780715942],
#     [-0.9789426326751709, 2.3358187675476074, 0.43286600708961487],
#     [-0.9789426326751709, 2.3358187675476074, 0.022988110780715942],
#     [-0.9789426326751709, 1.7575550079345703, 0.43286600708961487],
#     [-0.9789426326751709, 1.7575550079345703, 0.022988110780715942]],
#    'center': {'x': -0.7489657998085022,
#     'y': 2.046686887741089,
#     'z': 0.2279270589351654},
#    'size': {'x': 0.4599536657333374,
#     'y': 0.5782637596130371,
#     'z': 0.4098778963088989}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Cabinet_892e0164',
#   'position': {'x': -1.4787566661834717,
#    'y': 2.046686887741089,
#    'z': 0.39212119579315186},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 2.0383081436157227,
#   'objectType': 'Cabinet',
#   'objectId': 'Cabinet|-01.48|+02.05|+00.39',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-1.019256591796875,
#      2.335818290710449,
#      0.4328664541244507],
#     [-1.019256591796875, 2.335818290710449, 0.022988110780715942],
#     [-1.019256591796875, 1.7575554847717285, 0.4328664541244507],
#     [-1.019256591796875, 1.7575554847717285, 0.022988110780715942],
#     [-1.4792101383209229, 2.335818290710449, 0.4328664541244507],
#     [-1.4792101383209229, 2.335818290710449, 0.022988110780715942],
#     [-1.4792101383209229, 1.7575554847717285, 0.4328664541244507],
#     [-1.4792101383209229, 1.7575554847717285, 0.022988110780715942]],
#    'center': {'x': -1.249233365058899,
#     'y': 2.046686887741089,
#     'z': 0.2279272824525833},
#    'size': {'x': 0.45995354652404785,
#     'y': 0.5782628059387207,
#     'z': 0.40987834334373474}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Cabinet_e1875ba5',
#   'position': {'x': -2.474677562713623,
#    'y': 2.046686887741089,
#    'z': 0.39212119579315186},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 1.6169238090515137,
#   'objectType': 'Cabinet',
#   'objectId': 'Cabinet|-02.47|+02.05|+00.39',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-2.015777111053467,
#      2.33581805229187,
#      0.4328663945198059],
#     [-2.015777111053467, 2.33581805229187, 0.022988110780715942],
#     [-2.015777111053467, 1.7575557231903076, 0.4328663945198059],
#     [-2.015777111053467, 1.7575557231903076, 0.022988110780715942],
#     [-2.475731372833252, 2.33581805229187, 0.4328663945198059],
#     [-2.475731372833252, 2.33581805229187, 0.022988110780715942],
#     [-2.475731372833252, 1.7575557231903076, 0.4328663945198059],
#     [-2.475731372833252, 1.7575557231903076, 0.022988110780715942]],
#    'center': {'x': -2.2457542419433594,
#     'y': 2.046686887741089,
#     'z': 0.22792725265026093},
#    'size': {'x': 0.45995426177978516,
#     'y': 0.5782623291015625,
#     'z': 0.40987828373908997}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Cabinet_4d20afde',
#   'position': {'x': -0.47972574830055237,
#    'y': 2.046686887741089,
#    'z': 0.39212119579315186},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 2.7735869884490967,
#   'objectType': 'Cabinet',
#   'objectId': 'Cabinet|-00.48|+02.05|+00.39',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.01912561058998108,
#      2.3358187675476074,
#      0.43286651372909546],
#     [-0.01912561058998108, 2.3358187675476074, 0.022988110780715942],
#     [-0.01912561058998108, 1.7575550079345703, 0.43286651372909546],
#     [-0.01912561058998108, 1.7575550079345703, 0.022988110780715942],
#     [-0.47907930612564087, 2.3358187675476074, 0.43286651372909546],
#     [-0.47907930612564087, 2.3358187675476074, 0.022988110780715942],
#     [-0.47907930612564087, 1.7575550079345703, 0.43286651372909546],
#     [-0.47907930612564087, 1.7575550079345703, 0.022988110780715942]],
#    'center': {'x': -0.24910245835781097,
#     'y': 2.046686887741089,
#     'z': 0.2279273122549057},
#    'size': {'x': 0.4599536955356598,
#     'y': 0.5782637596130371,
#     'z': 0.4098784029483795}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Cabinet_31eeb70a',
#   'position': {'x': -2.5507774353027344,
#    'y': 0.4901084005832672,
#    'z': 0.6467460989952087},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 0.9680132865905762,
#   'objectType': 'Cabinet',
#   'objectId': 'Cabinet|-02.55|+00.49|+00.65',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-2.0908241271972656,
#      0.6662567853927612,
#      0.6873210072517395],
#     [-2.0908241271972656, 0.6662567853927612, 0.0851520299911499],
#     [-2.0908241271972656, 0.09206116199493408, 0.6873210072517395],
#     [-2.0908241271972656, 0.09206116199493408, 0.0851520299911499],
#     [-2.5507774353027344, 0.6662567853927612, 0.6873210072517395],
#     [-2.5507774353027344, 0.6662567853927612, 0.0851520299911499],
#     [-2.5507774353027344, 0.09206116199493408, 0.6873210072517395],
#     [-2.5507774353027344, 0.09206116199493408, 0.0851520299911499]],
#    'center': {'x': -2.32080078125,
#     'y': 0.37915897369384766,
#     'z': 0.3862365186214447},
#    'size': {'x': 0.45995330810546875,
#     'y': 0.5741956233978271,
#     'z': 0.6021689772605896}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Cabinet_b1a58862',
#   'position': {'x': -1.5548566579818726,
#    'y': 0.4901084005832672,
#    'z': 0.6467460989952087},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 1.525033712387085,
#   'objectType': 'Cabinet',
#   'objectId': 'Cabinet|-01.55|+00.49|+00.65',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-1.0949029922485352,
#      0.6135903596878052,
#      0.6873210072517395],
#     [-1.0949029922485352, 0.6135903596878052, 0.08830595016479492],
#     [-1.0949029922485352, 0.08730843663215637, 0.6873210072517395],
#     [-1.0949029922485352, 0.08730843663215637, 0.08830595016479492],
#     [-1.554856777191162, 0.6135903596878052, 0.6873210072517395],
#     [-1.554856777191162, 0.6135903596878052, 0.08830595016479492],
#     [-1.554856777191162, 0.08730843663215637, 0.6873210072517395],
#     [-1.554856777191162, 0.08730843663215637, 0.08830595016479492]],
#    'center': {'x': -1.3248798847198486,
#     'y': 0.35044941306114197,
#     'z': 0.3878134787082672},
#    'size': {'x': 0.45995378494262695,
#     'y': 0.5262819528579712,
#     'z': 0.5990150570869446}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Cabinet_0db79cde',
#   'position': {'x': -1.5910099744796753,
#    'y': 0.4901084005832672,
#    'z': 0.6469160914421082},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 1.4967725276947021,
#   'objectType': 'Cabinet',
#   'objectId': 'Cabinet|-01.59|+00.49|+00.65',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-1.5918564796447754,
#      0.6135901808738708,
#      0.6873209476470947],
#     [-1.5918564796447754, 0.6135901808738708, 0.08480590581893921],
#     [-1.5918564796447754, 0.09206074476242065, 0.6873209476470947],
#     [-1.5918564796447754, 0.09206074476242065, 0.08480590581893921],
#     [-2.0518100261688232, 0.6135901808738708, 0.6873209476470947],
#     [-2.0518100261688232, 0.6135901808738708, 0.08480590581893921],
#     [-2.0518100261688232, 0.09206074476242065, 0.6873209476470947],
#     [-2.0518100261688232, 0.09206074476242065, 0.08480590581893921]],
#    'center': {'x': -1.8218332529067993,
#     'y': 0.35282546281814575,
#     'z': 0.38606342673301697},
#    'size': {'x': 0.45995354652404785,
#     'y': 0.5215294361114502,
#     'z': 0.6025150418281555}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Cabinet_34f4da5a',
#   'position': {'x': -0.5558257102966309,
#    'y': 0.4901084005832672,
#    'z': 0.6467460989952087},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 2.3899290561676025,
#   'objectType': 'Cabinet',
#   'objectId': 'Cabinet|-00.56|+00.49|+00.65',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.09587210416793823,
#      0.6733886003494263,
#      0.6873210072517395],
#     [-0.09587210416793823, 0.6733886003494263, 0.09180593490600586],
#     [-0.09587210416793823, 0.09206116199493408, 0.6873210072517395],
#     [-0.09587210416793823, 0.09206116199493408, 0.09180593490600586],
#     [-0.5558257699012756, 0.6733886003494263, 0.6873210072517395],
#     [-0.5558257699012756, 0.6733886003494263, 0.09180593490600586],
#     [-0.5558257699012756, 0.09206116199493408, 0.6873210072517395],
#     [-0.5558257699012756, 0.09206116199493408, 0.09180593490600586]],
#    'center': {'x': -0.32584893703460693,
#     'y': 0.3827248811721802,
#     'z': 0.3895634710788727},
#    'size': {'x': 0.4599536657333374,
#     'y': 0.5813274383544922,
#     'z': 0.5955150723457336}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Cabinet_d9228b96',
#   'position': {'x': -0.5950890779495239,
#    'y': 0.4901084005832672,
#    'z': 0.6480000019073486},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 2.3534789085388184,
#   'objectType': 'Cabinet',
#   'objectId': 'Cabinet|-00.60|+00.49|+00.65',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.5967355966567993,
#      0.6153503060340881,
#      0.6873210072517395],
#     [-0.5967355966567993, 0.6153503060340881, 0.08680593967437744],
#     [-0.5967355966567993, 0.09206122159957886, 0.6873210072517395],
#     [-0.5967355966567993, 0.09206122159957886, 0.08680593967437744],
#     [-1.0566892623901367, 0.6153503060340881, 0.6873210072517395],
#     [-1.0566892623901367, 0.6153503060340881, 0.08680593967437744],
#     [-1.0566892623901367, 0.09206122159957886, 0.6873210072517395],
#     [-1.0566892623901367, 0.09206122159957886, 0.08680593967437744]],
#    'center': {'x': -0.826712429523468,
#     'y': 0.3537057638168335,
#     'z': 0.38706347346305847},
#    'size': {'x': 0.4599536657333374,
#     'y': 0.5232890844345093,
#     'z': 0.6005150675773621}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Cabinet_96086447',
#   'position': {'x': -1.5149099826812744,
#    'y': 2.046686887741089,
#    'z': 0.3922911286354065},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 2.015864849090576,
#   'objectType': 'Cabinet',
#   'objectId': 'Cabinet|-01.51|+02.05|+00.39',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-1.5149097442626953,
#      2.3358185291290283,
#      0.43286603689193726],
#     [-1.5149097442626953, 2.3358185291290283, 0.022988110780715942],
#     [-1.5149097442626953, 1.7575552463531494, 0.43286603689193726],
#     [-1.5149097442626953, 1.7575552463531494, 0.022988110780715942],
#     [-1.9748635292053223, 2.3358185291290283, 0.43286603689193726],
#     [-1.9748635292053223, 2.3358185291290283, 0.022988110780715942],
#     [-1.9748635292053223, 1.7575552463531494, 0.43286603689193726],
#     [-1.9748635292053223, 1.7575552463531494, 0.022988110780715942]],
#    'center': {'x': -1.7448866367340088,
#     'y': 2.046686887741089,
#     'z': 0.2279270738363266},
#    'size': {'x': 0.45995378494262695,
#     'y': 0.5782632827758789,
#     'z': 0.4098779261112213}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'CoffeeMachine_61ed6a3e',
#   'position': {'x': -2.9382107257843018,
#    'y': 0.9253724813461304,
#    'z': 3.605863571166992},
#   'rotation': {'x': 0.0027945146430283785,
#    'y': 89.64253234863281,
#    'z': 0.0007038136245682836},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': True,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': True,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': True,
#   'mass': 5.0,
#   'salientMaterials': ['Plastic'],
#   'receptacleObjectIds': [],
#   'distance': 2.114391326904297,
#   'objectType': 'CoffeeMachine',
#   'objectId': 'CoffeeMachine|-02.94|+00.93|+03.61',
#   'assetId': 'coffee_machine_26',
#   'parentReceptacles': ['CounterTop|-02.78|+00.97|+03.49'],
#   'controlledObjects': [],
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-2.6543664932250977,
#      1.3359581232070923,
#      3.829800605773926],
#     [-2.6543664932250977, 1.3359581232070923, 3.383897304534912],
#     [-2.6543664932250977, 0.925369143486023, 3.829800605773926],
#     [-2.6543664932250977, 0.925369143486023, 3.383897304534912],
#     [-3.088862419128418, 1.3359581232070923, 3.829800605773926],
#     [-3.088862419128418, 1.3359581232070923, 3.383897304534912],
#     [-3.088862419128418, 0.925369143486023, 3.829800605773926],
#     [-3.088862419128418, 0.925369143486023, 3.383897304534912]],
#    'center': {'x': -2.871614456176758,
#     'y': 1.1306636333465576,
#     'z': 3.606848955154419},
#    'size': {'x': 0.4344959259033203,
#     'y': 0.41058897972106934,
#     'z': 0.44590330123901367}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-2.6529462337493896,
#      0.9253730177879333,
#      3.384582281112671],
#     [-2.6557273864746094, 0.9253675937652588, 3.829801559448242],
#     [-3.090160846710205, 0.9253746271133423, 3.827087879180908],
#     [-3.0873796939849854, 0.9253800511360168, 3.381868362426758],
#     [-2.652939796447754, 1.3359510898590088, 3.384587287902832],
#     [-2.6557207107543945, 1.335945725440979, 3.8298068046569824],
#     [-3.0901541709899902, 1.3359527587890625, 3.8270931243896484],
#     [-3.0873730182647705, 1.3359582424163818, 3.381873607635498]]}},
#  {'name': 'CounterTop_0aab7a9f',
#   'position': {'x': -1.3660999536514282,
#    'y': 0.9520000219345093,
#    'z': 0.3490000069141388},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': ['Apple|-01.64|+00.96|+00.50',
#    'SoapBottle|-01.58|+00.92|+00.30',
#    'SaltShaker|-01.84|+00.92|+00.31',
#    'PepperShaker|-01.93|+00.92|+00.40',
#    'ButterKnife|-02.21|+00.92|+00.62',
#    'Spatula|-02.24|+00.92|+00.55',
#    'Microwave|-00.39|+00.92|+00.22',
#    'Faucet|-01.08|+00.92|+00.03'],
#   'distance': 1.800700306892395,
#   'objectType': 'CounterTop',
#   'objectId': 'CounterTop|-01.37|+00.95|+00.35',
#   'assetId': '',
#   'parentReceptacles': ['Sink|-01.11|+00.93|+00.34|SinkBasin'],
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.07996892929077148,
#      0.9230000972747803,
#      0.6789878010749817],
#     [-0.07996892929077148, 0.9230000972747803, -0.018307745456695557],
#     [-0.07996892929077148, 0.9169411659240723, 0.6789878010749817],
#     [-0.07996892929077148, 0.9169411659240723, -0.018307745456695557],
#     [-2.5630383491516113, 0.9230000972747803, 0.6789878010749817],
#     [-2.5630383491516113, 0.9230000972747803, -0.018307745456695557],
#     [-2.5630383491516113, 0.9169411659240723, 0.6789878010749817],
#     [-2.5630383491516113, 0.9169411659240723, -0.018307745456695557]],
#    'center': {'x': -1.3215036392211914,
#     'y': 0.9199706315994263,
#     'z': 0.33034002780914307},
#    'size': {'x': 2.48306941986084,
#     'y': 0.006058931350708008,
#     'z': 0.6972955465316772}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'CounterTop_8700c90d',
#   'position': {'x': -2.7809998989105225,
#    'y': 0.9710000157356262,
#    'z': 3.48799991607666},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': ['CoffeeMachine|-02.94|+00.93|+03.61',
#    'Potato|-02.62|+00.96|+03.34'],
#   'distance': 1.9894527196884155,
#   'objectType': 'CounterTop',
#   'objectId': 'CounterTop|-02.78|+00.97|+03.49',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-2.469322681427002,
#      0.9420000314712524,
#      3.8494949340820312],
#     [-2.469322681427002, 0.9420000314712524, 3.1209211349487305],
#     [-2.469322681427002, 0.9256260395050049, 3.8494949340820312],
#     [-2.469322681427002, 0.9256260395050049, 3.1209211349487305],
#     [-3.1282148361206055, 0.9420000314712524, 3.8494949340820312],
#     [-3.1282148361206055, 0.9420000314712524, 3.1209211349487305],
#     [-3.1282148361206055, 0.9256260395050049, 3.8494949340820312],
#     [-3.1282148361206055, 0.9256260395050049, 3.1209211349487305]],
#    'center': {'x': -2.7987687587738037,
#     'y': 0.9338130354881287,
#     'z': 3.485208034515381},
#    'size': {'x': 0.6588921546936035,
#     'y': 0.01637399196624756,
#     'z': 0.7285737991333008}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Cup_a7567614',
#   'position': {'x': -2.9096503257751465,
#    'y': 0.7180262804031372,
#    'z': 2.906604528427124},
#   'rotation': {'x': 359.62158203125,
#    'y': 0.07412630319595337,
#    'z': 1.040429711341858},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': True,
#   'isBroken': False,
#   'canFillWithLiquid': True,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': True,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': True,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.4000000059604645,
#   'salientMaterials': ['Ceramic'],
#   'receptacleObjectIds': [],
#   'distance': 1.4274874925613403,
#   'objectType': 'Cup',
#   'objectId': 'Cup|-02.91|+00.72|+02.91',
#   'assetId': 'Cup_26',
#   'parentReceptacles': ['DiningTable|-02.73|00.00|+02.61'],
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-2.8534865379333496,
#      0.8898239135742188,
#      2.964681625366211],
#     [-2.8534865379333496, 0.8898239135742188, 2.8456058502197266],
#     [-2.8534865379333496, 0.7171568870544434, 2.964681625366211],
#     [-2.8534865379333496, 0.7171568870544434, 2.8456058502197266],
#     [-2.9725356101989746, 0.8898239135742188, 2.964681625366211],
#     [-2.9725356101989746, 0.8898239135742188, 2.8456058502197266],
#     [-2.9725356101989746, 0.7171568870544434, 2.964681625366211],
#     [-2.9725356101989746, 0.7171568870544434, 2.8456058502197266]],
#    'center': {'x': -2.913011074066162,
#     'y': 0.803490400314331,
#     'z': 2.9051437377929688},
#    'size': {'x': 0.119049072265625,
#     'y': 0.1726670265197754,
#     'z': 0.11907577514648438}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-2.850064754486084,
#      0.7192704081535339,
#      2.9660117626190186],
#     [-2.9690473079681396, 0.7169198989868164, 2.9662063121795654],
#     [-2.969221830368042, 0.7158953547477722, 2.8472042083740234],
#     [-2.8502390384674072, 0.7182459235191345, 2.8470096588134766],
#     [-2.853445053100586, 0.8902652263641357, 2.9645445346832275],
#     [-2.9724278450012207, 0.8879147171974182, 2.9647390842437744],
#     [-2.972602128982544, 0.886890172958374, 2.8457369804382324],
#     [-2.8536195755004883, 0.8892407417297363, 2.8455424308776855]]}},
#  {'name': 'DiningTable_fc569e38',
#   'position': {'x': -2.733119249343872,
#    'y': -0.0029630064964294434,
#    'z': 2.6074187755584717},
#   'rotation': {'x': 0.6307877898216248,
#    'y': 270.0075988769531,
#    'z': 0.02157984860241413},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': True,
#   'mass': 85.0,
#   'salientMaterials': ['Metal', 'Plastic'],
#   'receptacleObjectIds': ['Bowl|-02.64|+00.72|+02.87',
#    'Pot|-02.54|+00.72|+02.55',
#    'Cup|-02.91|+00.72|+02.91',
#    'Bread|-02.87|+00.77|+02.41'],
#   'distance': 1.42999267578125,
#   'objectType': 'DiningTable',
#   'objectId': 'DiningTable|-02.73|00.00|+02.61',
#   'assetId': 'Dining_Table_21_1',
#   'parentReceptacles': ['Floor|-00.05|+00.00|+00.00'],
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-2.4004480838775635,
#      0.723442018032074,
#      3.0456318855285645],
#     [-2.4004480838775635, 0.723442018032074, 2.1798439025878906],
#     [-2.4004480838775635, -0.0048653483390808105, 3.0456318855285645],
#     [-2.4004480838775635, -0.0048653483390808105, 2.1798439025878906],
#     [-3.0888993740081787, 0.723442018032074, 3.0456318855285645],
#     [-3.0888993740081787, 0.723442018032074, 2.1798439025878906],
#     [-3.0888993740081787, -0.0048653483390808105, 3.0456318855285645],
#     [-3.0888993740081787, -0.0048653483390808105, 2.1798439025878906]],
#    'center': {'x': -2.744673728942871,
#     'y': 0.3592883348464966,
#     'z': 2.6127378940582275},
#    'size': {'x': 0.6884512901306152,
#     'y': 0.7283073663711548,
#     'z': 0.8657879829406738}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-3.080922842025757,
#      -0.0057756719179451466,
#      3.0457940101623535],
#     [-3.080841302871704, -0.006055596750229597, 2.1800787448883057],
#     [-2.3928165435791016, 0.001549798995256424, 2.1801412105560303],
#     [-2.392897844314575, 0.0018297242932021618, 3.045856475830078],
#     [-3.0888993740081787, 0.7158381938934326, 3.045559883117676],
#     [-3.088818073272705, 0.7155582904815674, 2.179844856262207],
#     [-2.4007930755615234, 0.7231636643409729, 2.1799070835113525],
#     [-2.400874614715576, 0.7234435677528381, 3.0456223487854004]]}},
#  {'name': 'DiningTable_b56db783',
#   'position': {'x': -0.4880039393901825,
#    'y': -0.003265202045440674,
#    'z': 3.1827175617218018},
#   'rotation': {'x': -3.1751536880619824e-05,
#    'y': 270.0013122558594,
#    'z': 2.0997365936636925e-05},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': True,
#   'mass': 85.0,
#   'salientMaterials': ['Metal', 'Plastic'],
#   'receptacleObjectIds': ['Toaster|-00.29|+00.86|+03.52',
#    'Knife|-00.58|+00.87|+03.31',
#    'Plate|-00.45|+00.86|+02.93',
#    'Mug|-00.21|+00.86|+02.72'],
#   'distance': 2.960900068283081,
#   'objectType': 'DiningTable',
#   'objectId': 'DiningTable|-00.49|00.00|+03.18',
#   'assetId': 'Dining_Table_21_3',
#   'parentReceptacles': ['Floor|-00.05|+00.00|+00.00'],
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.0766063928604126,
#      0.8615326881408691,
#      3.7043113708496094],
#     [-0.0766063928604126, 0.8615326881408691, 2.652553081512451],
#     [-0.0766063928604126, 0.0005911588668823242, 3.7043113708496094],
#     [-0.0766063928604126, 0.0005911588668823242, 2.652553081512451],
#     [-0.9089882969856262, 0.8615326881408691, 3.7043113708496094],
#     [-0.9089882969856262, 0.8615326881408691, 2.652553081512451],
#     [-0.9089882969856262, 0.0005911588668823242, 3.7043113708496094],
#     [-0.9089882969856262, 0.0005911588668823242, 2.652553081512451]],
#    'center': {'x': -0.4927973449230194,
#     'y': 0.43106192350387573,
#     'z': 3.1784322261810303},
#    'size': {'x': 0.8323819041252136,
#     'y': 0.8609415292739868,
#     'z': 1.0517582893371582}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-0.9089678525924683,
#      0.0005922110285609961,
#      3.704310417175293],
#     [-0.9089885950088501, 0.0005922794807702303, 2.6525702476501465],
#     [-0.0766274631023407, 0.0005918997339904308, 2.6525540351867676],
#     [-0.07660672068595886, 0.0005918312817811966, 3.704293966293335],
#     [-0.9089674949645996, 0.8615304827690125, 3.704310417175293],
#     [-0.9089882373809814, 0.861530601978302, 2.6525704860687256],
#     [-0.07662707567214966, 0.8615302443504333, 2.6525540351867676],
#     [-0.07660633325576782, 0.8615301251411438, 3.704294204711914]]}},
#  {'name': 'DishSponge_c51474f6',
#   'position': {'x': -0.9010491967201233,
#    'y': 0.7889033555984497,
#    'z': 0.2600114047527313},
#   'rotation': {'x': 0.24406982958316803,
#    'y': 30.033191680908203,
#    'z': 2.2814173698425293},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': False,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': True,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.029999997466802597,
#   'salientMaterials': ['Sponge'],
#   'receptacleObjectIds': None,
#   'distance': 2.2291007041931152,
#   'objectType': 'DishSponge',
#   'objectId': 'DishSponge|-00.90|+00.79|+00.26',
#   'assetId': 'Dish_Sponge_1',
#   'parentReceptacles': ['Sink|-01.11|+00.93|+00.34|SinkBasin'],
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.8343914747238159,
#      0.8145919442176819,
#      0.3391096591949463],
#     [-0.8343914747238159, 0.8145919442176819, 0.1814292073249817],
#     [-0.8343914747238159, 0.7850537896156311, 0.3391096591949463],
#     [-0.8343914747238159, 0.7850537896156311, 0.1814292073249817],
#     [-0.9684135913848877, 0.8145919442176819, 0.3391096591949463],
#     [-0.9684135913848877, 0.8145919442176819, 0.1814292073249817],
#     [-0.9684135913848877, 0.7850537896156311, 0.3391096591949463],
#     [-0.9684135913848877, 0.7850537896156311, 0.1814292073249817]],
#    'center': {'x': -0.9014025330543518,
#     'y': 0.7998228669166565,
#     'z': 0.260269433259964},
#    'size': {'x': 0.13402211666107178,
#     'y': 0.02953815460205078,
#     'z': 0.1576804518699646}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-0.8343914747238159,
#      0.7879820466041565,
#      0.30171865224838257],
#     [-0.898029625415802, 0.7850538492202759, 0.3384948968887329],
#     [-0.9675716757774353, 0.7856457233428955, 0.21820548176765442],
#     [-0.903933584690094, 0.7885738611221313, 0.18142923712730408],
#     [-0.8352333903312683, 0.8140001893043518, 0.30233338475227356],
#     [-0.8988715410232544, 0.8110719919204712, 0.3391096293926239],
#     [-0.9684135913848877, 0.811663806438446, 0.2188202291727066],
#     [-0.9047755002975464, 0.8145920038223267, 0.18204398453235626]]}},
#  {'name': 'Drawer_1f9ce187',
#   'position': {'x': -0.32583174109458923,
#    'y': 0.6963000297546387,
#    'z': 0.41378599405288696},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': True,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 2.6643192768096924,
#   'objectType': 'Drawer',
#   'objectId': 'Drawer|-00.33|+00.70|+00.41',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.09474670886993408,
#      0.8124101161956787,
#      0.6544560194015503],
#     [-0.09474670886993408, 0.8124101161956787, 0.17311596870422363],
#     [-0.09474670886993408, 0.6308157444000244, 0.6544560194015503],
#     [-0.09474670886993408, 0.6308157444000244, 0.17311596870422363],
#     [-0.5561165809631348, 0.8124101161956787, 0.6544560194015503],
#     [-0.5561165809631348, 0.8124101161956787, 0.17311596870422363],
# ...
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': [],
#   'distance': 3.5494892597198486,
#   'objectType': 'StoveBurner',
#   'objectId': 'StoveBurner|-00.54|+00.92|+04.27',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.4145098924636841,
#      0.9269309639930725,
#      4.395589351654053],
#     [-0.4145098924636841, 0.9269309639930725, 4.1528096199035645],
#     [-0.4145098924636841, 0.8984319567680359, 4.395589351654053],
#     [-0.4145098924636841, 0.8984319567680359, 4.1528096199035645],
#     [-0.6623542308807373, 0.9269309639930725, 4.395589351654053],
#     [-0.6623542308807373, 0.9269309639930725, 4.1528096199035645],
#     [-0.6623542308807373, 0.8984319567680359, 4.395589351654053],
#     [-0.6623542308807373, 0.8984319567680359, 4.1528096199035645]],
#    'center': {'x': -0.5384320616722107,
#     'y': 0.9126814603805542,
#     'z': 4.274199485778809},
#    'size': {'x': 0.24784433841705322,
#     'y': 0.02849900722503662,
#     'z': 0.24277973175048828}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'StoveKnob_e4d0b5f1',
#   'position': {'x': -0.06430000066757202,
#    'y': 1.0907000303268433,
#    'z': 4.222350597381592},
#   'rotation': {'x': -0.0, 'y': -0.0, 'z': 73.8651351928711},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': False,
#   'toggleable': True,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': None,
#   'distance': 3.8288300037384033,
#   'objectType': 'StoveKnob',
#   'objectId': 'StoveKnob|-00.06|+01.09|+04.22',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': ['StoveBurner|-00.54|+00.92|+04.27'],
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.05340823531150818,
#      1.134190320968628,
#      4.259034633636475],
#     [-0.05340823531150818, 1.134190320968628, 4.185666561126709],
#     [-0.05340823531150818, 1.0530502796173096, 4.259034633636475],
#     [-0.05340823531150818, 1.0530502796173096, 4.185666561126709],
#     [-0.09538185596466064, 1.134190320968628, 4.259034633636475],
#     [-0.09538185596466064, 1.134190320968628, 4.185666561126709],
#     [-0.09538185596466064, 1.0530502796173096, 4.259034633636475],
#     [-0.09538185596466064, 1.0530502796173096, 4.185666561126709]],
#    'center': {'x': -0.07439504563808441,
#     'y': 1.0936203002929688,
#     'z': 4.222350597381592},
#    'size': {'x': 0.041973620653152466,
#     'y': 0.08114004135131836,
#     'z': 0.07336807250976562}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'StoveKnob_f1534319',
#   'position': {'x': -0.06430000066757202,
#    'y': 1.0907000303268433,
#    'z': 4.382349491119385},
#   'rotation': {'x': -0.0, 'y': -0.0, 'z': 73.8651351928711},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': False,
#   'toggleable': True,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': None,
#   'distance': 3.9441964626312256,
#   'objectType': 'StoveKnob',
#   'objectId': 'StoveKnob|-00.06|+01.09|+04.38',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': ['StoveBurner|-00.25|+00.92|+04.27'],
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.05340823531150818,
#      1.134190320968628,
#      4.419033527374268],
#     [-0.05340823531150818, 1.134190320968628, 4.345665454864502],
#     [-0.05340823531150818, 1.0530502796173096, 4.419033527374268],
#     [-0.05340823531150818, 1.0530502796173096, 4.345665454864502],
#     [-0.09538185596466064, 1.134190320968628, 4.419033527374268],
#     [-0.09538185596466064, 1.134190320968628, 4.345665454864502],
#     [-0.09538185596466064, 1.0530502796173096, 4.419033527374268],
#     [-0.09538185596466064, 1.0530502796173096, 4.345665454864502]],
#    'center': {'x': -0.07439504563808441,
#     'y': 1.0936203002929688,
#     'z': 4.382349491119385},
#    'size': {'x': 0.041973620653152466,
#     'y': 0.08114004135131836,
#     'z': 0.07336807250976562}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'StoveKnob_30d24d96',
#   'position': {'x': -0.06430000066757202,
#    'y': 1.0907000303268433,
#    'z': 4.782350063323975},
#   'rotation': {'x': -0.0, 'y': -0.0, 'z': 73.8651351928711},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': False,
#   'toggleable': True,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': None,
#   'distance': 4.245299339294434,
#   'objectType': 'StoveKnob',
#   'objectId': 'StoveKnob|-00.06|+01.09|+04.78',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': ['StoveBurner|-00.54|+00.92|+04.67'],
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.05340823531150818,
#      1.134190320968628,
#      4.819034099578857],
#     [-0.05340823531150818, 1.134190320968628, 4.745666027069092],
#     [-0.05340823531150818, 1.0530502796173096, 4.819034099578857],
#     [-0.05340823531150818, 1.0530502796173096, 4.745666027069092],
#     [-0.09538185596466064, 1.134190320968628, 4.819034099578857],
#     [-0.09538185596466064, 1.134190320968628, 4.745666027069092],
#     [-0.09538185596466064, 1.0530502796173096, 4.819034099578857],
#     [-0.09538185596466064, 1.0530502796173096, 4.745666027069092]],
#    'center': {'x': -0.07439504563808441,
#     'y': 1.0936203002929688,
#     'z': 4.782350063323975},
#    'size': {'x': 0.041973620653152466,
#     'y': 0.08114004135131836,
#     'z': 0.07336807250976562}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'StoveKnob_32879446',
#   'position': {'x': -0.06430000066757202,
#    'y': 1.0907000303268433,
#    'z': 4.632350444793701},
#   'rotation': {'x': -0.0, 'y': -0.0, 'z': 73.8651351928711},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': False,
#   'toggleable': True,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': None,
#   'distance': 4.130419731140137,
#   'objectType': 'StoveKnob',
#   'objectId': 'StoveKnob|-00.06|+01.09|+04.63',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': ['StoveBurner|-00.25|+00.92|+04.67'],
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.05340823531150818,
#      1.134190320968628,
#      4.669034481048584],
#     [-0.05340823531150818, 1.134190320968628, 4.595666408538818],
#     [-0.05340823531150818, 1.0530502796173096, 4.669034481048584],
#     [-0.05340823531150818, 1.0530502796173096, 4.595666408538818],
#     [-0.09538185596466064, 1.134190320968628, 4.669034481048584],
#     [-0.09538185596466064, 1.134190320968628, 4.595666408538818],
#     [-0.09538185596466064, 1.0530502796173096, 4.669034481048584],
#     [-0.09538185596466064, 1.0530502796173096, 4.595666408538818]],
#    'center': {'x': -0.07439504563808441,
#     'y': 1.0936203002929688,
#     'z': 4.632350444793701},
#    'size': {'x': 0.041973620653152466,
#     'y': 0.08114004135131836,
#     'z': 0.07336807250976562}},
#   'objectOrientedBoundingBox': None},
#  {'name': 'Toaster_f745e839',
#   'position': {'x': -0.28601884841918945,
#    'y': 0.8615336418151855,
#    'z': 3.521000385284424},
#   'rotation': {'x': -3.438547719269991e-05,
#    'y': 269.9967346191406,
#    'z': -5.285102088237181e-05},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': True,
#   'toggleable': True,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': True,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': True,
#   'mass': 5.0,
#   'salientMaterials': ['Metal'],
#   'receptacleObjectIds': [],
#   'distance': 3.187044143676758,
#   'objectType': 'Toaster',
#   'objectId': 'Toaster|-00.29|+00.86|+03.52',
#   'assetId': 'Toaster_26',
#   'parentReceptacles': ['DiningTable|-00.49|00.00|+03.18'],
#   'controlledObjects': [],
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-0.12858232855796814,
#      1.042596459388733,
#      3.67392635345459],
#     [-0.12858232855796814, 1.042596459388733, 3.368069648742676],
#     [-0.12858232855796814, 0.8615309000015259, 3.67392635345459],
#     [-0.12858232855796814, 0.8615309000015259, 3.368069648742676],
#     [-0.48862871527671814, 1.042596459388733, 3.67392635345459],
#     [-0.48862871527671814, 1.042596459388733, 3.368069648742676],
#     [-0.48862871527671814, 0.8615309000015259, 3.67392635345459],
#     [-0.48862871527671814, 0.8615309000015259, 3.368069648742676]],
#    'center': {'x': -0.30860552191734314,
#     'y': 0.9520636796951294,
#     'z': 3.520998001098633},
#    'size': {'x': 0.36004638671875,
#     'y': 0.18106555938720703,
#     'z': 0.30585670471191406}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-0.48862898349761963,
#      0.8615310788154602,
#      3.673905372619629],
#     [-0.4886111617088318, 0.8615310192108154, 3.3680691719055176],
#     [-0.12858186662197113, 0.861531138420105, 3.3680901527404785],
#     [-0.12859971821308136, 0.8615312576293945, 3.67392635345459],
#     [-0.4886290729045868, 1.0425963401794434, 3.673905372619629],
#     [-0.48861122131347656, 1.0425962209701538, 3.3680689334869385],
#     [-0.1285819411277771, 1.0425963401794434, 3.3680899143218994],
#     [-0.12859979271888733, 1.042596459388733, 3.67392635345459]]}},
#  {'name': 'Tomato_f8bc52bb',
#   'position': {'x': -1.1579999923706055,
#    'y': 0.8532715439796448,
#    'z': 0.3240000009536743},
#   'rotation': {'x': -0.0, 'y': 0.0, 'z': -7.602677669638069e-06},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': False,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': False,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': True,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': True,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.11999998986721039,
#   'salientMaterials': ['Food'],
#   'receptacleObjectIds': None,
#   'distance': 1.9798420667648315,
#   'objectType': 'Tomato',
#   'objectId': 'Tomato|-01.16|+00.85|+00.32',
#   'assetId': 'Tomato_26',
#   'parentReceptacles': ['Sink|-01.11|+00.93|+00.34|SinkBasin'],
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-1.0940630435943604,
#      0.9212047457695007,
#      0.3879370093345642],
#     [-1.0940630435943604, 0.9212047457695007, 0.2600629925727844],
#     [-1.0940630435943604, 0.7853383421897888, 0.3879370093345642],
#     [-1.0940630435943604, 0.7853383421897888, 0.2600629925727844],
#     [-1.2219369411468506, 0.9212047457695007, 0.3879370093345642],
#     [-1.2219369411468506, 0.9212047457695007, 0.2600629925727844],
#     [-1.2219369411468506, 0.7853383421897888, 0.3879370093345642],
#     [-1.2219369411468506, 0.7853383421897888, 0.2600629925727844]],
#    'center': {'x': -1.1579999923706055,
#     'y': 0.8532715439796448,
#     'z': 0.3240000009536743},
#    'size': {'x': 0.12787389755249023,
#     'y': 0.13586640357971191,
#     'z': 0.12787401676177979}},
#   'objectOrientedBoundingBox': {'cornerPoints': [[-1.0940630435943604,
#      0.7853383421897888,
#      0.3879370093345642],
#     [-1.2219370603561401, 0.7853383421897888, 0.3879370093345642],
#     [-1.2219370603561401, 0.7853383421897888, 0.2600629925727844],
#     [-1.0940630435943604, 0.7853383421897888, 0.2600629925727844],
#     [-1.0940629243850708, 0.9212047457695007, 0.3879370093345642],
#     [-1.2219369411468506, 0.9212047457695007, 0.3879370093345642],
#     [-1.2219369411468506, 0.9212047457695007, 0.2600629925727844],
#     [-1.0940629243850708, 0.9212047457695007, 0.2600629925727844]]}},
#  {'name': 'Window_b57e75ad',
#   'position': {'x': -3.0759999752044678,
#    'y': 1.593000054359436,
#    'z': 1.3619999885559082},
#   'rotation': {'x': 90.0, 'y': 89.99993896484375, 'z': 0.0},
#   'visible': False,
#   'isInteractable': False,
#   'receptacle': False,
#   'toggleable': False,
#   'isToggled': False,
#   'breakable': True,
#   'isBroken': False,
#   'canFillWithLiquid': False,
#   'isFilledWithLiquid': False,
#   'fillLiquid': None,
#   'dirtyable': False,
#   'isDirty': False,
#   'canBeUsedUp': False,
#   'isUsedUp': False,
#   'cookable': False,
#   'isCooked': False,
#   'temperature': 'RoomTemp',
#   'isHeatSource': False,
#   'isColdSource': False,
#   'sliceable': False,
#   'isSliced': False,
#   'openable': False,
#   'isOpen': False,
#   'openness': 0.0,
#   'pickupable': False,
#   'isPickedUp': False,
#   'moveable': False,
#   'mass': 0.0,
#   'salientMaterials': None,
#   'receptacleObjectIds': None,
#   'distance': 0.7767667174339294,
#   'objectType': 'Window',
#   'objectId': 'Window|-03.08|+01.59|+01.36',
#   'assetId': '',
#   'parentReceptacles': None,
#   'controlledObjects': None,
#   'isMoving': False,
#   'axisAlignedBoundingBox': {'cornerPoints': [[-3.05180025100708,
#      2.0199973583221436,
#      1.7891453504562378],
#     [-3.05180025100708, 2.0199973583221436, 0.8988543748855591],
#     [-3.05180025100708, 1.1778740882873535, 1.7891453504562378],
#     [-3.05180025100708, 1.1778740882873535, 0.8988543748855591],
#     [-3.1553444862365723, 2.0199973583221436, 1.7891453504562378],
#     [-3.1553444862365723, 2.0199973583221436, 0.8988543748855591],
#     [-3.1553444862365723, 1.1778740882873535, 1.7891453504562378],
#     [-3.1553444862365723, 1.1778740882873535, 0.8988543748855591]],
#    'center': {'x': -3.103572368621826,
#     'y': 1.5989357233047485,
#     'z': 1.3439998626708984},
#    'size': {'x': 0.10354423522949219,
#     'y': 0.84212327003479,
#     'z': 0.8902909755706787}},
#   'objectOrientedBoundingBox': None}]

# %%
def encode_feedback(event, controller, target_name):
    
    agent_position = event.metadata["agent"]["position"]
    data = controller.last_event.metadata['objects']
    
    index_location = next((index for index, item in enumerate(data) if item['name'] == target_name), None)
    is_found = data[index_location]['visible']
    
    if is_found:
        reward = +10
    else:
        reward = -0.05
    
    return None, random.random(), is_found, None

# %% [markdown]
# ---
